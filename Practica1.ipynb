# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sympy as sympy

# %%
t1 = np.arange(0,8*np.pi,0.1) #Vector de valores de 0 a 2pi en saltos de 0.1 unidades
pts1 = np.arange(0,8*np.pi,np.pi/4)
dif1 = 2*np.sin(2*t1)
dif1_pts = 2*np.sin(2*pts1)
ceros1 = np.zeros(np.size(dif1))

plt.plot(t1,dif1)
plt.plot(t1,ceros1,"--k")
plt.plot(pts1,dif1_pts,"*r")

# %%
t2 = np.arange(0,8*np.pi, 0.1)
pts2 = np.arange(0,8*np.pi,np.pi/4)
dif2 = -0.1 * np.exp(-0.1*t2) * np.cos(np.sqrt(3.99)*t2)
dif_pts = -0.1 * np.exp(-0.1*pts2) * np.cos(np.sqrt(3.99)*pts2)
ceros2 = np.zeros(np.size(t2))

plt.plot(t2,dif2)
plt.plot(t2,ceros2,"--k")
plt.plot(pts2,dif_pts,"*r")

# %%
t3 = np.arange(0,20,0.1)
dif3 = np.exp(-t3) - np.exp(-4*t3)
dif4 = t3*np.exp(t3)
plt.plot(t3,dif3)
